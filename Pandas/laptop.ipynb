# %%
import pandas as pd

# %%
df=pd.read_csv("laptopPrice.csv")

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.duplicated().sum()
# Out:
# 21

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(['weight','msoffice','ram_type','Touchscreen'],axis=1,inplace=True)

# %%
df.drop(['warranty','rating'],axis=1,inplace=True)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb      ssd  \
# 0      ASUS           Intel        Core i3            10th   4 GB     0 GB
# 1    Lenovo           Intel        Core i3            10th   4 GB     0 GB
# 2    Lenovo           Intel        Core i3            10th   4 GB     0 GB
# 3      ASUS           Intel        Core i5            10th   8 GB   512 GB
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     0 GB
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB  1024 GB
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB  1024 GB
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB  1024 GB
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB  1024 GB
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB   512 GB
#
# ...

# %%
df.to_csv("cleaned_laptop_dataset.csv",index=False)

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
brand_dict={'ASUS':0, 'Lenovo':1, 'acer':2, 'Avita':3, 'HP':4, 'DELL':5, 'MSI':6, 'APPLE':7}

# %%
df['brand']=df['brand'].map(brand_dict)

# %%
df
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb      ssd  \
# 0        0           Intel        Core i3            10th   4 GB     0 GB
# 1        1           Intel        Core i3            10th   4 GB     0 GB
# 2        1           Intel        Core i3            10th   4 GB     0 GB
# 3        0           Intel        Core i5            10th   8 GB   512 GB
# 4        0           Intel   Celeron Dual   Not Available   4 GB     0 GB
# ..     ...             ...            ...             ...    ...      ...
# 818      0             AMD        Ryzen 9   Not Available   4 GB  1024 GB
# 819      0             AMD        Ryzen 9   Not Available   4 GB  1024 GB
# 820      0             AMD        Ryzen 9   Not Available   4 GB  1024 GB
# 821      0             AMD        Ryzen 9   Not Available   4 GB  1024 GB
# 822      1             AMD        Ryzen 5            10th   8 GB   512 GB
#
#          hdd       os  os_bit graphic_card_gb   Price  Number of Ratings  \
# ...

# %%
df['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
process_dict={'Intel':0, 'AMD':1, 'M1':2}

# %%
df['processor_brand']=df['processor_brand'].map(process_dict)

# %%
df
# Out:
#      brand  processor_brand processor_name processor_gnrtn ram_gb      ssd  \
# 0        0                0        Core i3            10th   4 GB     0 GB
# 1        1                0        Core i3            10th   4 GB     0 GB
# 2        1                0        Core i3            10th   4 GB     0 GB
# 3        0                0        Core i5            10th   8 GB   512 GB
# 4        0                0   Celeron Dual   Not Available   4 GB     0 GB
# ..     ...              ...            ...             ...    ...      ...
# 818      0                1        Ryzen 9   Not Available   4 GB  1024 GB
# 819      0                1        Ryzen 9   Not Available   4 GB  1024 GB
# 820      0                1        Ryzen 9   Not Available   4 GB  1024 GB
# 821      0                1        Ryzen 9   Not Available   4 GB  1024 GB
# 822      1                1        Ryzen 5            10th   8 GB   512 GB
#
# ...

# %%
df['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
dict_procename={'Core i3':0, 'Core i5':1, 'Celeron Dual':2, 'Ryzen 5':3, 'Core i7':4,
       'Core i9':5, 'M1':6, 'Pentium Quad':7, 'Ryzen 3':8, 'Ryzen 7':9, 'Ryzen 9':10}

# %%
df['processor_name']=df['processor_name'].map(dict_procename)

# %%
df['processor_gnrtn'].unique()
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
proc_gnrtn_dict={'10th':0, 'Not Available':1, '11th':2, '7th':3, '8th':4, '9th':5, '4th':6,
       '12th':7}

# %%
df['processor_gnrtn']=df['processor_gnrtn'].map(proc_gnrtn_dict)

# %%
df['ram_gb'].unique()
# Out:
# array(['4 GB', '8 GB', '16 GB', '32 GB'], dtype=object)

# %%
ramgb_dict={'4 GB':0, '8 GB':1, '16 GB':2, '32 GB':3}

# %%
df['ram_gb']=df['ram_gb'].map(ramgb_dict)

# %%
df.dtypes
# Out:
# brand                 int64
# processor_brand       int64
# processor_name        int64
# processor_gnrtn       int64
# ram_gb                int64
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# Price                 int64
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df['ssd'].unique()
# Out:
# array(['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB',
#        '3072 GB'], dtype=object)

# %%
ssd_dict={'0 GB':0, '512 GB':1, '256 GB':2, '128 GB':3, '1024 GB':4, '2048 GB':5,
       '3072 GB':6}

# %%
df['ssd']=df['ssd'].map(ssd_dict)

# %%
df['hdd'].unique()
# Out:
# array(['1024 GB', '0 GB', '512 GB', '2048 GB'], dtype=object)

# %%
hdd_dict={'1024 GB':0, '0 GB':1, '512 GB':2, '2048 GB':3}

# %%
df['hdd']=df['hdd'].map(hdd_dict)

# %%
df['os'].unique()
# Out:
# array(['Windows', 'DOS', 'Mac'], dtype=object)

# %%
os_dict={'Windows':0, 'DOS':1, 'Mac':2}

# %%
df['os']=df['os'].map(os_dict)

# %%
df['os_bit'].unique()
# Out:
# array(['64-bit', '32-bit'], dtype=object)

# %%
osbit_dict={'64-bit':0, '32-bit':1}

# %%
df['os_bit']=df['os_bit'].map(osbit_dict)

# %%
df['graphic_card_gb'].unique()
# Out:
# array(['0 GB', '2 GB', '4 GB', '6 GB', '8 GB'], dtype=object)

# %%
graphic_dict={'0 GB':0, '2 GB':1, '4 GB':2, '6 GB':3, '8 GB':4}

# %%
df['graphic_card_gb']=df['graphic_card_gb'].map(graphic_dict)

# %%
df.dtypes
# Out:
# brand                int64
# processor_brand      int64
# processor_name       int64
# processor_gnrtn      int64
# ram_gb               int64
# ssd                  int64
# hdd                  int64
# os                   int64
# os_bit               int64
# graphic_card_gb      int64
# Price                int64
# Number of Ratings    int64
# Number of Reviews    int64
# dtype: object

# %%
df.to_csv("cleaned_laptop_datasets.csv",index=False)
